# %%
from openai import OpenAI
import json
import matplotlib.pyplot as plt
from collections import Counter

import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize
# Out:
# [nltk_data] Downloading package punkt to /Users/gilad/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
client = OpenAI(api_key = "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")

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>From "Semantic reconstruction of continuous language from non-invasive brain recordings" by Huth et al.</b>

# %% [markdown]
# # Overview

# %% [markdown]
# Based on the results shown above, Semantic Decoding systems showed a correlation between lexical "Concreteness rating" to decoding performance. Semantic Decoding seems to have trouble decoding words rated as abstract.
# Inspired by this result I wanted to analyze the performance of semantic decoding with measurements that takes into account larger linguistic structures composed of several words and even full sentences. For this puprpose I used Geroge Lakoff's "Conceptual Metaphors Theory". The theory describe systematic ways to analyze the meaning of longer linguistic elements through "frames" or "metaphors" that according to the theory undelies the cognitive construction of the sentences. For example, the theory posits that both the sentences "His head is full of ideas" and "The dog is inside the doghouse" share the same conceptual meatphor of "Containment" which make them semantically similiar even though their lexical content is different.
#
# I used GPT4, with context and examples, to analyze both the input and the output of the Semantic Decoding pipeline. With this analysis in place I am looking to develop reliable measures to understand if the Semantic Decoding preserve this semantic strcuture, and if specific failure modse can be detected.

# %% [markdown]
# ## Loading the story text file (Input)

# %%
with open('texts/if this hair could talk.txt') as f:
    lines = f.readlines()
    input_text = "\r\n".join(lines)

# %% [markdown]
# ## Loading the decoded text file (Output)

# %%
with open('texts/if this hair could talk - decoded.txt') as f:
    lines = f.readlines()
    output_text = "\r\n".join(lines)

# %% [markdown]
# ## Prompt for Semantic analysis in ChatGPT

# %% [markdown]
# ### Find Semantic Alignment between Texts

# %%
with open('prompts/getting alignment between texts.txt') as f:
    lines = f.readlines()
    prompt_alignment = "\r\n".join(lines)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 with open('prompts/getting alignment between texts.txt') as f:
#       2     lines = f.readlines()
#       3     prompt_alignment = "\r\n".join(lines)
#
# File ~/opt/anaconda3/envs/semantic_decoding/lib/python3.9/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prompts/getting alignment between texts.txt'

# %% [markdown]
# ### Prompt for GPT 4

# %% [markdown]
# You have a good understanding of text's meaning, I need your help to evaluate the semantic similarity between these two texts, consider several factors for comparison of meaning:
#
# Subject Matter: Are both texts discussing similar topics or themes?
# Narrative Style: Do the texts share a similar narrative or storytelling approach?
# Purpose or Intent: Are the texts aiming to convey the same kind of message or purpose?
# Tone and Language: Do they share a similar tone or use of language?
# Contextual Details: Are specific details, characters, or events in one text mirrored or referenced in the other?
# Analysis of the Texts:
#
#
# can you find paragraphs in text1 and tex2 that seems similair in meaning (in whatever criteria you can consider), preferably parts of the texts that are aligned and are roughly at the same part of the text. write them now for me please, one next to each other, take your time.
#
# Arrange the results in the following JSON format , make the result a clean json please:
#
# {
#     "comparison_pairs" : [{"text1_excerpt": "" , "text2_excerpt" : "" , explanation: "" }, {"text1_excerpt": "" , "text2_excerpt" : "" , explanation: "" }, {"text1_excerpt": "" , "text2_excerpt" : "" , explanation: "" }]
# }

# %%
response = client.chat.completions.create(
  model="gpt-4-1106-preview",
  messages=[
    {"role": "system", "content": prompt_alignment},
    {"role": "user", "content": "text1: " + input_text + "\r\n" + " text2: " + output_text},
  ]
)

# %% [markdown]
# ### Semantic Alignment of Decoding Input and Output From GPT4

# %%
semantic_alignment_json = {
    "comparison_pairs": [
        {
            "text1_excerpt": "So my doctor calls me later that day and she goes, Melanie, are you with your loved ones? Are you sitting down? I'm like, I'm with my three children all the time. One of them's eating right now. The other one's sleeping right now. So yes, what's going on?",
            "text2_excerpt": "My doctor had to call me up and ask if I had been sleeping with my boyfriend or my sister we both had our own rooms we all slept together",
            "explanation": "Both excerpts involve a conversation with a doctor, indicating a significant moment or revelation. The tone is conversational and somewhat informal, focusing on personal and family dynamics."
        },
        {
            "text1_excerpt": "And she goes, Melanie. IV has to have surgery or her brain won't grow. And when your daughter gets to have skull surgery, you get all the top doctors.",
            "text2_excerpt": "Then she goes she can't go she has to leave or else she will never get to her daughter who is about to have the best childhood life you can imagine",
            "explanation": "These excerpts both address a critical decision or action needed for the well-being of a child. The tone is serious and conveys the weight of the situation."
        },
        {
            "text1_excerpt": "I go home and I'm like, good lord. Like, I thought that was going to a well check. And they go and drop this bomb on me that ivy has to have surgery.",
            "text2_excerpt": "I went home and thought that I had forgotten something I was going to check my laptop and get some homework done and I forgot my computer",
            "explanation": "Both passages describe a return home after a significant event, reflecting on what just happened. The tone is reflective, and there's an element of surprise or unexpectedness in both."
        },
        {
            "text1_excerpt": "So I'm like, okay, so that's kind of cute. I don't know, is this a problem?",
            "text2_excerpt": "I'm like okay so that isn't really a good example I don't know if this is true but it is what I feel is a reasonable point",
            "explanation": "These excerpts show the narrators contemplating a situation and expressing uncertainty or doubt about its seriousness or validity. The language is informal and reflects a personal, introspective thought process."
        },
        {
            "text1_excerpt": "But my only question that I was able to say was, so were you going to shave her hair off?",
            "text2_excerpt": "I told her I have a question I asked her why she wasn't wearing her hat",
            "explanation": "Both passages depict the narrator focusing on a seemingly minor detail (hair shaving, hat wearing) in the midst of a more significant context. This reflects a coping mechanism or a way to deal with overwhelming information."
        },
        {
            "text1_excerpt": "And I said, what's going on? And she goes, ivy looks great.",
            "text2_excerpt": "And he was shaking I said oh my god it's not true I'm not saying it is but I just didn't understand what he was talking about",
            "explanation": "These excerpts involve a direct interaction with another character, where the narrator is seeking clarification or information. The tone is one of concern, and there's a degree of emotional intensity in the interactions."
        },
        {
            "text1_excerpt": "And so, day of the surgery comes. And we are prepared, and we're ready.",
            "text2_excerpt": "The day of the baby comes and we are all ready to go in an hour and a half time we get the kids and are waiting for the doctor to finish his examination",
            "explanation": "Both sections describe a day of significant event (surgery, birth) and the preparation involved. There's a sense of anticipation and readiness conveyed in both, highlighting the importance of the events."
        },
        {
            "text1_excerpt": "And they go and drop this bomb on me that ivy has to have surgery. So the thing with this surgery is you have to wait. You have to wait until your daughter's a certain size or your son whatever. They can't be too tiny because it's really invasive.",
            "text2_excerpt": "it can cause complications it's the worst case scenario of miscarriage and i have to tell them this to my best friend to which she responds oh please don't be the one to say it i had to do it",
            "explanation": "Both excerpts convey the emotional weight of medical decisions and their potential complications. They emphasize the seriousness of health-related situations"
        },
        {
            "text1_excerpt": "And so, I get it from the chair, and I'm like, I have to have that conversation with Avery and Eliza. I have to tell them their sister didn't make it.",
            "text2_excerpt": "i then started thinking about the possibility of being able to tell her parents and brothers and sisters she might be pregnant",
            "explanation": "Both excerpts discuss an impending conversation with family relatives"
        }
    
    ]
}

# %% [markdown]
# ## calculate span of excerpts similarity and percentage of the input/output text

# %%
text1_with_high_similarity = sum([len(item['text1_excerpt']) for item in semantic_alignment_json['comparison_pairs']])

# %%
text2_with_high_similarity = sum([len(item['text2_excerpt']) for item in semantic_alignment_json['comparison_pairs']])

# %% [markdown]
# ## Percentage of high similiarity in texts

# %%
(text_with_high_similarity / len(input_text) ) * 100
# Out:
# 13.397180673625309

# %%
( text2_with_high_similarity / len(output_text) ) * 100
# Out:
# 19.208141198918746

# %%
metaphor_analysis_prompt = """
Background on Conceptual Metaphor Theory (CMT):
Conceptual Metaphor Theory, developed by George Lakoff and Mark Johnson, posits that metaphors are fundamental to understanding abstract concepts and are deeply embedded in everyday language. CMT suggests that our understanding of abstract concepts is often structured by more concrete, physical experiences.

Common Metaphors in CMT:

Containment (e.g., "in trouble," "out of danger")
War (e.g., "attack a problem," "defend a point") not in terms of tone or seriousness, but in terms of structure 
Building (e.g., "foundation of an argument," "structure of a theory")
Temperature (e.g., "warm relationship," "cold response")
Journey (e.g., "a long way to go," "crossroads in life")
Analysis Structure:
Please analyze the provided text for the presence of the above metaphors. The analysis should be structured in a JSON-like format, focusing on identifying only the most evident metaphors. If a metaphor isn't clearly present, it should not be forced. Each metaphor identified should be enclosed within a <CMT_Analysis> tag, with separate elements for the text segment, the metaphor, and a brief explanation.

Example JSON Format:

[
    {
    "text":[Text Segment],
    "metaphor":[Identified Metaphor],
    "explanation":[Brief Explanation of How the Metaphor Applies]
    },
    {
    "text":[Text Segment 2],
    "metaphor":[Identified Metaphor 2 ],
    "explanation":[Brief Explanation of How the Metaphor Applies 2]
    }    
]

(make sure that you use " for quotes and not ') also, make sure you close the array }]
Task:
Analyze the following text using the guidelines above:\r\n
"""

# %%
def analyze_metaphors_in_text(story):
    prompt = metaphor_analysis_prompt + story
    
    response = client.completions.create(
    model="gpt-3.5-turbo-instruct",
    max_tokens=1000,
    temperature=1.2,
    prompt = prompt)
    
    return response.choices[0].text

# %%
def divide_into_paragraphs(text, sentences_per_paragraph=8):
    # Split the text into sentences
    sentences = sent_tokenize(text)

    # Group sentences into paragraphs
    paragraphs = []
    for i in range(0, len(sentences), sentences_per_paragraph):
        paragraph = ' '.join(sentences[i:i+sentences_per_paragraph])
        paragraphs.append(paragraph)

    return paragraphs

# %% [markdown]
# # Analyze the semantic decoding Input according to CMT

# %%
paragraphs = divide_into_paragraphs(story)

# %%
paragraphs[1]
# Out:
# "What do you need X-rays for? Sure, her head looks kind of funny but that's a little endearing to me. I think it's adorable. So my doctor calls me later that day and she goes, Melanie, are you with your loved ones? Are you sitting down? I'm like, I'm with my three children all the time. One of them's eating right now. The other one's sleeping right now."

# %%
analysis_result_jsons = []
for paragraph in paragraphs:
    print(paragraph)
    json_metaphors = analyze_metaphors_in_text(paragraph)
    json_metaphors = json_metaphors.replace('\r', '').replace('\n', '').strip()
    json_metaphors_formatted = json.loads(json_metaphors)
    analysis_result_jsons.append(json_metaphors_formatted)
# Out:
#  So my pediatrician tells me when I go to see her at my daughter's one month well check appointment. Melanie, you got to go to the hospital. I need you to get X-rays of IV skull because something's wrong and I'm going to tell you what's going on in a minute. And I'm like, well, I have a babysitter for like 20 more minutes so can I do it next week? She goes, Melanie, I'm serious. You need to go right now. I'm like, okay, call a babysitter. And I go on to get these X-rays done and I'm like, my baby's a month old.
# What do you need X-rays for? Sure, her head looks kind of funny but that's a little endearing to me. I think it's adorable. So my doctor calls me later that day and she goes, Melanie, are you with your loved ones? Are you sitting down? I'm like, I'm with my three children all the time. One of them's eating right now. The other one's sleeping right now.
# ---------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Display the analysis result, for inspection and "Human in the loop" feedback

# %%
metaphors_analysis = analysis_result_jsons[1]

# %%
for idx,text_segment in enumerate(metaphors_analysis):
    print("idx:",idx)
    [print(analysis) for analysis in text_segment.items()]
# Out:
# idx: 0
# ('text', 'her head looks kind of funny')
# ('metaphor', 'Container')
# ('explanation', 'The concept of appearance is being structured by the container metaphor with head being the container and funny being the content within the container.')
# idx: 1
# ('text', 'my doctor calls me later that day')
# ('metaphor', 'Journey')
# ('explanation', 'The concept of time passing and changes occurring is represented through the metaphor of a journey.')
# idx: 2
# ('text', "I'm with my three children all the time")
# ('metaphor', 'Container')
# ('explanation', 'The idea of constantly being with someone is represented through the container metaphor, with children being the contents within the container.')
# idx: 3
# ('text', "one of them's eating right now")
# ('metaphor', 'Building')
# ('explanation', "The perception of one's child growing and developing is structured through the metaphor of constructing a building.")
# idx: 4
# ('text', "the other one's sleeping right now")
# ...

# %% [markdown]
# ## Remove segement that are wrongfully analyzed

# %%
result = metaphors_analysis.pop(2)

# %% [markdown]
# # Comapre results

# %% [markdown]
# ### Baseline

# %% [markdown]
# ### Per Segment

# %%
metaphors_analysis
# Out:
# [{'text': 'her head looks kind of funny',
#   'metaphor': 'Container',
#   'explanation': 'The concept of appearance is being structured by the container metaphor with head being the container and funny being the content within the container.'},
#  {'text': 'my doctor calls me later that day',
#   'metaphor': 'Journey',
#   'explanation': 'The concept of time passing and changes occurring is represented through the metaphor of a journey.'},
#  {'text': "one of them's eating right now",
#   'metaphor': 'Building',
#   'explanation': "The perception of one's child growing and developing is structured through the metaphor of constructing a building."},
#  {'text': "the other one's sleeping right now",
#   'metaphor': 'War',
#   'explanation': 'The act of sleep and peacefulness is represented through the metaphor of defending against enemies or danger.'}]

# %%
metaphor_counts =  Counter()
for paragraph_analysis in analysis_result_jsons:
    metaphor_counts += Counter([text['metaphor'] for text in metaphors_analysis if text['metaphor']])

# %%
# Creating a histogram
plt.bar(metaphor_counts.keys(), metaphor_counts.values())
plt.xlabel('Metaphor')
plt.ylabel('Number of appearences')
plt.title('Histogram of Metaphor Usage')
# Out:
# Text(0.5, 1.0, 'Histogram of Metaphor Usage')

# %%
analysis_result_jsons[0]
# Out:
# {'text': "So my pediatrician tells me when I go to see her at my daughter's one month well check appointment.",
#  'metaphor': 'Journey',
#  'explanation': "The use of language about a doctor's appointment as a 'journey' suggests that the experience of going to the appointment is more than just a physical trip to the doctor, but rather an important and potentially daunting milestone for the mother and her daughter."}

# %%
analysis_result_jsons[0]['metaphor']
# Out:
# 'Journey'

# %% [markdown]
# ### Per Story

# %%
# Conclusion

# %%
def get_metaphors_analysis_from_gpt(text):

    # API endpoint for GPT-4 Turbo (this is hypothetical and may not be correct)
    api_url = 'https://api.openai.com/v1/chat/completions'

    # Your OpenAI API key (replace with your actual API key)
    api_key = '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'

    # The data to send in the POST request
    data = {
        'prompt': metaphor_analysis_prompt + text ,
        'max_tokens': 500  # You can adjust this value based on your needs
    }

    # Set the headers including the API key
    headers = {
        'Authorization': f'Bearer {api_key}',
        'Content-Type': 'application/json'
    }

    # Make the POST request
    response = requests.post(api_url, headers=headers, data=json.dumps(data))

    # Check if the request was successful and print the response
    if response.status_code == 200:
        return response
    else:
        print(response)
        return "Error"
